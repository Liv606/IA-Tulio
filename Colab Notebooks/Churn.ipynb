# %% [markdown]
# # Análise de Previsão de Churn

# %%
# Montar o drive para que o nosso script consiga acessar a base de dados.
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     728             try:
# --> 729                 ident, reply = self.session.recv(self.stdin_socket, 0)
#     730             except Exception:
#
# /usr/local/lib/python3.7/dist-packages/jupyter_client/session.py in recv(self, socket, mode, content, copy)
#     802         try:
# --> 803             msg_list = socket.recv_multipart(mode, copy=copy)
#     804         except zmq.ZMQError as e:
#
# /usr/local/lib/python3.7/dist-packages/zmq/sugar/socket.py in recv_multipart(self, flags, copy, track)
#     582         """
# --> 583         parts = [self.recv(flags, copy=copy, track=track)]
#     584         # have first part already, only loop while more to receive
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._recv_copy()
#
# /usr/local/lib/python3.7/dist-packages/zmq/backend/cython/checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-1e649a5ff36c> in <module>()
#       1 # Montar o drive para que o nosso script consiga acessar a base de dados.
#       2 from google.colab import drive
# ----> 3 drive.mount('/content/drive')
#
# /usr/local/lib/python3.7/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, use_metadata_server)
#     258       with _output.use_tags('dfs-auth-dance'):
#     259         with open(fifo, 'w') as fifo_file:
# --> 260           fifo_file.write(get_code(auth_prompt) + '\n')
#     261       wrote_to_fifo = True
#     262     elif case == 5:
#
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     702             self._parent_ident,
#     703             self._parent_header,
# --> 704             password=False,
#     705         )
#     706
#
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     732             except KeyboardInterrupt:
#     733                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 734                 raise KeyboardInterrupt
#     735             else:
#     736                 break
#
# KeyboardInterrupt:

# %%
import os
os.chdir("/content/drive/My Drive/Facamp/5° Semestre/IA")  #MAPEAR PARA O LOCAL NO DRIVE ONDE SE ENCONTRA ESSE ARQUIVO

# %%
# !ls #Ver a localização desse script nas pastas. o ARQUIVO DE CHURN DEVE ESTAR LISTADO ABAIXO
# Out:
# 201910647_ASR2.gdoc  201910647_ASR4.gdoc  Churn.ipynb	       Untitled
# 201910647_ASR3.gdoc  Churn.csv		  Churn_solução.ipynb

# %% [markdown]
# Neste script iremos prever a possibilidade de um cliente deixar de ser cliente de uma empresa de telecom usando o algoritmo KNN (K Nearest Neighbor).

# %% [markdown]
# # Setup
#
# ##Importar bibliotecas necessárias

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

# %matplotlib inline

# %% [markdown]
# # Exercício 1
#
# Carregue o arquivo csv chamado 'Churn.csv' usando pandas e salve a base em uma variável chamada df. (dica: pd.read_csv('<nome_da_base.csv>')) Imprima as primeiras 10 linhas do dataframe e verifique se tudo foi carregado corretamente. (dica: df.head())

# %%
df = pd.read_csv('Churn.csv')

# %%
df.head(10)
# Out:
#    intl_plan  voice_mail_plan  ...  number_customer_service_calls  churned
# 0        0.0              1.0  ...                            1.0    False
# 1        0.0              1.0  ...                            1.0    False
# 2        0.0              0.0  ...                            0.0    False
# 3        1.0              0.0  ...                            2.0    False
# 4        1.0              0.0  ...                            3.0    False
# 5        1.0              0.0  ...                            0.0    False
# 6        0.0              NaN  ...                            3.0    False
# 7        1.0              0.0  ...                            0.0    False
# 8        0.0              0.0  ...                            1.0    False
# 9        1.0              1.0  ...                            NaN    False
#
# [10 rows x 17 columns]

# %% [markdown]
# # Exercício 2:
#
# Que coluna indica se o cliente deixou ou não a empresa? Quantos clientes existem na sua base de dados? (dica: len(?))

# %%
#coluna rótulo: 'churned'
# número de clientes: 5000
len(df)
# Out:
# 5000

# %% [markdown]
# # Exercício 3:
#
# Use df.describe() para explorar cada coluna. Por que o count (total de valores) é diferente para cada coluna e diferente de 5000?

# %%
df.describe()
#pois existem valores faltantes na tabela
# Out:
#          intl_plan  ...  number_customer_service_calls
# count  4815.000000  ...                    4593.000000
# mean      0.095119  ...                       1.568909
# std       0.293410  ...                       1.303008
# min       0.000000  ...                       0.000000
# 25%       0.000000  ...                       1.000000
# 50%       0.000000  ...                       1.000000
# 75%       0.000000  ...                       2.000000
# max       1.000000  ...                       9.000000
#
# [8 rows x 16 columns]

# %% [markdown]
# # Exercício 4:
#
# Preencha os valores faltantes com a média de todo a base! (dica: df.fillna(df.mean())) Verifique se o count agora está 5000 para todas as colunas.

# %%
df = df.fillna(df.mean())
df.describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-2396bf80da1f> in <module>()
# ----> 1 df = df.fillna(df.mean())
#       2 df.describe()
#
# NameError: name 'df' is not defined

# %% [markdown]
# # Exercício 5:
#
# Verifique o número de colunas da base de dados (dica: df.shape)
#
# Separe a base de dados em atributos de entrada e rótulos. Associe os atributos a variável X e os rótulos a variável y.
#
# Verifique as primeiras linhas das bases separadas.

# %%
df.shape

# %%
X = df.iloc[:,0:16]
y = df.iloc[:,16]

# %%
X.head()

# %%
y.head()

# %% [markdown]
# # Exercício 6:
#
# Separa a base de treino (70%) e teste (30%) e associe-as as variáveis X_train, X_test, y_train, y_test (dica: train_test_split(X,y, test_size=0.3))

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3)

# %% [markdown]
# # Exercício 7:
#
# Crie um classificador KNN com 5 vizinhos. (hint: KNeighborsClassifier(n_neighbors=5))

# %%
knn = KNeighborsClassifier(n_neighbors=9)

# %% [markdown]
# # Exercício 8:
#
# Apresente a base de treino para ajustar o modelo. (hint: knn.fit(<base_de_treino_atributos>, <base_de_treino_rotulos>))

# %%
knn = knn.fit(X_train, y_train)

# %% [markdown]
# # Exercício 9:
#
# Use o modelo para fazer previsões na base de teste. Associe os resultados de previsão a variável y_pred

# %%
y_pred = knn.predict(X_test)

# %% [markdown]
# # Exercício 10:
#
# Determine quão acurado é o seu modelo. (dica: accuracy_score(<rotulo_real>, <rotulo_previsto>))

# %%
 accuracy_score(y_test,y_pred)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-86e1b10703d2> in <module>()
# ----> 1 accuracy_score(y_test,y_pred)
#
# NameError: name 'accuracy_score' is not defined

# %% [markdown]
# # Exercício 11 (Opcional)
#
# Tente diferentes valores de k entre 1 e 10 e veja se consegue achar um resultado melhor.
